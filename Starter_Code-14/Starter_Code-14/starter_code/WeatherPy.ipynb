# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 585

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city

    city_url = f"{url}&q={city}"
    #print(city_url)
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]


        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | adamstown
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | vorgashor
# Processing Record 4 of Set 1 | kodiak
# Processing Record 5 of Set 1 | port-aux-francais
# Processing Record 6 of Set 1 | kapuskasing
# Processing Record 7 of Set 1 | invercargill
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | iskateley
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | enewetak
# Processing Record 13 of Set 1 | acapulco de juarez
# Processing Record 14 of Set 1 | bethel
# Processing Record 15 of Set 1 | ribeira grande
# Processing Record 16 of Set 1 | luza
# Processing Record 17 of Set 1 | kendari
# Processing Record 18 of Set 1 | erseke
# Processing Record 19 of Set 1 | alofi
# Processing Record 20 of Set 1 | grytviken
# Processing Record 21 of Set 1 | georgetown
# Processing Record 22 of Set 1 | snyder
# Processing Record 23 of Set 1 | saipan
# Processing Record 24 of Set 1 | suva
# Processing Record 25 of Set 1 | rizokarpaso
# Processing Record 26 of Set 1 | kiunga
# Processing Record 27 of Set 1 | bejar
# Processing Record 28 of Set 1 | codrington
# Processing Record 29 of Set 1 | east london
# Processing Record 30 of Set 1 | vingt cinq
# City not found. Skipping...
# Processing Record 31 of Set 1 | yaren
# Processing Record 32 of Set 1 | hawaiian paradise park
# Processing Record 33 of Set 1 | tiksi
# Processing Record 34 of Set 1 | margaret river
# Processing Record 35 of Set 1 | yellowknife
# Processing Record 36 of Set 1 | salalah
# Processing Record 37 of Set 1 | mount gambier
# Processing Record 38 of Set 1 | dynow
# Processing Record 39 of Set 1 | luba
# Processing Record 40 of Set 1 | peniche
# Processing Record 41 of Set 1 | rikaze
# Processing Record 42 of Set 1 | ilulissat
# Processing Record 43 of Set 1 | kiuruvesi
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | menongue
# Processing Record 46 of Set 1 | arraial do cabo
# Processing Record 47 of Set 1 | general villegas
# Processing Record 48 of Set 1 | puerto natales
# Processing Record 49 of Set 1 | remire-montjoly
# Processing Record 50 of Set 1 | vilyuchinsk
# Processing Record 0 of Set 2 | great falls
# Processing Record 1 of Set 2 | wailua homesteads
# Processing Record 2 of Set 2 | matoury
# Processing Record 3 of Set 2 | cidade velha
# Processing Record 4 of Set 2 | cururupu
# Processing Record 5 of Set 2 | stanley
# Processing Record 6 of Set 2 | ahau
# City not found. Skipping...
# Processing Record 7 of Set 2 | le vauclin
# Processing Record 8 of Set 2 | okhotsk
# Processing Record 9 of Set 2 | west island
# Processing Record 10 of Set 2 | nar'yan-mar
# Processing Record 11 of Set 2 | waitangi
# Processing Record 12 of Set 2 | port glaud
# City not found. Skipping...
# Processing Record 13 of Set 2 | avarua
# Processing Record 14 of Set 2 | haiku-pauwela
# Processing Record 15 of Set 2 | edinburgh of the seven seas
# Processing Record 16 of Set 2 | dek'emhare
# Processing Record 17 of Set 2 | coari
# Processing Record 18 of Set 2 | fort bragg
# Processing Record 19 of Set 2 | albany
# Processing Record 20 of Set 2 | beteza
# City not found. Skipping...
# Processing Record 21 of Set 2 | udachny
# Processing Record 22 of Set 2 | ouellah
# City not found. Skipping...
# Processing Record 23 of Set 2 | ulladulla
# Processing Record 24 of Set 2 | longyearbyen
# Processing Record 25 of Set 2 | thanh pho uong bi
# Processing Record 26 of Set 2 | port mathurin
# Processing Record 27 of Set 2 | san martin
# Processing Record 28 of Set 2 | anadyr
# Processing Record 29 of Set 2 | salinopolis
# Processing Record 30 of Set 2 | thompson
# Processing Record 31 of Set 2 | mapimi
# Processing Record 32 of Set 2 | lipova
# Processing Record 33 of Set 2 | papatowai
# Processing Record 34 of Set 2 | canton
# Processing Record 35 of Set 2 | berezovyy
# Processing Record 36 of Set 2 | ndibene dahra
# Processing Record 37 of Set 2 | vadso
# Processing Record 38 of Set 2 | bozkurt
# Processing Record 39 of Set 2 | kataba
# Processing Record 40 of Set 2 | altamira
# Processing Record 41 of Set 2 | lihue
# Processing Record 42 of Set 2 | tindouf
# Processing Record 43 of Set 2 | swakopmund
# Processing Record 44 of Set 2 | kovdor
# Processing Record 45 of Set 2 | mount darwin
# Processing Record 46 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 47 of Set 2 | tsiombe
# Processing Record 48 of Set 2 | les avirons
# Processing Record 49 of Set 2 | al qaryatayn
# Processing Record 0 of Set 3 | den burg
# Processing Record 1 of Set 3 | ressano garcia
# Processing Record 2 of Set 3 | cove
# Processing Record 3 of Set 3 | grand island
# Processing Record 4 of Set 3 | labuan
# Processing Record 5 of Set 3 | quellon
# Processing Record 6 of Set 3 | aasiaat
# Processing Record 7 of Set 3 | aswan
# Processing Record 8 of Set 3 | nova sintra
# Processing Record 9 of Set 3 | bikenibeu village
# Processing Record 10 of Set 3 | calapan
# Processing Record 11 of Set 3 | mary
# Processing Record 12 of Set 3 | punta arenas
# Processing Record 13 of Set 3 | faya-largeau
# Processing Record 14 of Set 3 | ixtapa
# Processing Record 15 of Set 3 | college
# Processing Record 16 of Set 3 | bengkulu
# Processing Record 17 of Set 3 | dudinka
# Processing Record 18 of Set 3 | tottori
# Processing Record 19 of Set 3 | port elizabeth
# Processing Record 20 of Set 3 | ba
# City not found. Skipping...
# Processing Record 21 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 22 of Set 3 | cabo san lucas
# Processing Record 23 of Set 3 | greenville
# Processing Record 24 of Set 3 | saryaghash
# Processing Record 25 of Set 3 | qaqortoq
# Processing Record 26 of Set 3 | dhidhdhoo
# Processing Record 27 of Set 3 | axim
# Processing Record 28 of Set 3 | rancho palos verdes
# Processing Record 29 of Set 3 | prince george
# Processing Record 30 of Set 3 | keshod
# Processing Record 31 of Set 3 | uturoa
# Processing Record 32 of Set 3 | port lincoln
# Processing Record 33 of Set 3 | strezhevoy
# Processing Record 34 of Set 3 | port alfred
# Processing Record 35 of Set 3 | bayanhongor
# Processing Record 36 of Set 3 | bom jesus
# Processing Record 37 of Set 3 | olonkinbyen
# Processing Record 38 of Set 3 | pariaman
# Processing Record 39 of Set 3 | queenstown
# Processing Record 40 of Set 3 | mizdah
# Processing Record 41 of Set 3 | bryan
# Processing Record 42 of Set 3 | lushun
# Processing Record 43 of Set 3 | iqaluit
# Processing Record 44 of Set 3 | yangshuo
# Processing Record 45 of Set 3 | ashkelon
# Processing Record 46 of Set 3 | hasaki
# Processing Record 47 of Set 3 | puerto aysen
# Processing Record 48 of Set 3 | pisco
# Processing Record 49 of Set 3 | isangel
# Processing Record 0 of Set 4 | viedma
# Processing Record 1 of Set 4 | carnarvon
# Processing Record 2 of Set 4 | pyin oo lwin
# Processing Record 3 of Set 4 | i-n-salah
# Processing Record 4 of Set 4 | cable beach
# City not found. Skipping...
# Processing Record 5 of Set 4 | berlin
# Processing Record 6 of Set 4 | el daein
# City not found. Skipping...
# Processing Record 7 of Set 4 | bongor
# Processing Record 8 of Set 4 | praia
# Processing Record 9 of Set 4 | julio de castilhos
# Processing Record 10 of Set 4 | palmer
# Processing Record 11 of Set 4 | nova vicosa
# Processing Record 12 of Set 4 | klyuchi
# Processing Record 13 of Set 4 | praia da vitoria
# Processing Record 14 of Set 4 | palmas
# Processing Record 15 of Set 4 | talnakh
# Processing Record 16 of Set 4 | hayma'
# City not found. Skipping...
# Processing Record 17 of Set 4 | midvagur
# Processing Record 18 of Set 4 | mili
# Processing Record 19 of Set 4 | tinana
# City not found. Skipping...
# Processing Record 20 of Set 4 | an nuhud
# Processing Record 21 of Set 4 | goure
# Processing Record 22 of Set 4 | leh
# Processing Record 23 of Set 4 | hammerfest
# Processing Record 24 of Set 4 | mongo
# Processing Record 25 of Set 4 | morehead city
# Processing Record 26 of Set 4 | blackmans bay
# Processing Record 27 of Set 4 | seaside
# Processing Record 28 of Set 4 | shakawe
# Processing Record 29 of Set 4 | tadmur
# Processing Record 30 of Set 4 | sept-iles
# Processing Record 31 of Set 4 | nouadhibou
# Processing Record 32 of Set 4 | marsabit
# Processing Record 33 of Set 4 | kingston
# Processing Record 34 of Set 4 | lagoa
# Processing Record 35 of Set 4 | isafjordur
# Processing Record 36 of Set 4 | atafu village
# Processing Record 37 of Set 4 | choibalsan
# Processing Record 38 of Set 4 | komarichi
# Processing Record 39 of Set 4 | happy valley-goose bay
# Processing Record 40 of Set 4 | mingguang
# Processing Record 41 of Set 4 | gaiman
# Processing Record 42 of Set 4 | mugia
# Processing Record 43 of Set 4 | sainte-adresse
# Processing Record 44 of Set 4 | lincoln city
# Processing Record 45 of Set 4 | utrik
# Processing Record 46 of Set 4 | magdagachi
# Processing Record 47 of Set 4 | la sarre
# Processing Record 48 of Set 4 | colonia
# Processing Record 49 of Set 4 | afaahiti
# Processing Record 0 of Set 5 | ust-nera
# Processing Record 1 of Set 5 | sainyabuli
# Processing Record 2 of Set 5 | badger
# Processing Record 3 of Set 5 | tondano
# Processing Record 4 of Set 5 | cockburn town
# Processing Record 5 of Set 5 | fortuna
# Processing Record 6 of Set 5 | puerto baquerizo moreno
# Processing Record 7 of Set 5 | lebu
# Processing Record 8 of Set 5 | fale old settlement
# Processing Record 9 of Set 5 | city of balikpapan
# Processing Record 10 of Set 5 | dalbandin
# Processing Record 11 of Set 5 | narvik
# Processing Record 12 of Set 5 | lompoc
# Processing Record 13 of Set 5 | mahomet
# Processing Record 14 of Set 5 | mjolby
# Processing Record 15 of Set 5 | inarajan village
# Processing Record 16 of Set 5 | san pedro pochutla
# Processing Record 17 of Set 5 | basoda
# Processing Record 18 of Set 5 | chyst'
# City not found. Skipping...
# Processing Record 19 of Set 5 | sarzedo
# Processing Record 20 of Set 5 | labrador city
# Processing Record 21 of Set 5 | machakos
# Processing Record 22 of Set 5 | hanceville
# Processing Record 23 of Set 5 | wamba
# Processing Record 24 of Set 5 | margate
# Processing Record 25 of Set 5 | espargos
# City not found. Skipping...
# Processing Record 26 of Set 5 | montevideo
# Processing Record 27 of Set 5 | brookings
# Processing Record 28 of Set 5 | nemuro
# Processing Record 29 of Set 5 | tura
# Processing Record 30 of Set 5 | molde
# Processing Record 31 of Set 5 | chulucanas
# Processing Record 32 of Set 5 | puerto ayacucho
# Processing Record 33 of Set 5 | bakanas
# Processing Record 34 of Set 5 | mariehamn
# Processing Record 35 of Set 5 | val-d'or
# Processing Record 36 of Set 5 | sandnessjoen
# Processing Record 37 of Set 5 | tolanaro
# Processing Record 38 of Set 5 | yung shue wan
# Processing Record 39 of Set 5 | olyokminsk
# Processing Record 40 of Set 5 | magadan
# Processing Record 41 of Set 5 | piti village
# Processing Record 42 of Set 5 | antofagasta
# Processing Record 43 of Set 5 | omaha
# Processing Record 44 of Set 5 | skovorodino
# Processing Record 45 of Set 5 | taltal
# Processing Record 46 of Set 5 | flying fish cove
# Processing Record 47 of Set 5 | jogindarnagar
# Processing Record 48 of Set 5 | auki
# Processing Record 49 of Set 5 | al bardiyah
# Processing Record 0 of Set 6 | san patricio
# Processing Record 1 of Set 6 | tobi village
# City not found. Skipping...
# Processing Record 2 of Set 6 | twon-brass
# Processing Record 3 of Set 6 | 'ohonua
# City not found. Skipping...
# Processing Record 4 of Set 6 | castillos
# Processing Record 5 of Set 6 | nevesinje
# Processing Record 6 of Set 6 | okha
# Processing Record 7 of Set 6 | saudarkrokur
# Processing Record 8 of Set 6 | gunjur
# Processing Record 9 of Set 6 | lorengau
# Processing Record 10 of Set 6 | mawlamyinegyunn
# Processing Record 11 of Set 6 | santiago de cao
# Processing Record 12 of Set 6 | ursulo galvan
# Processing Record 13 of Set 6 | vostochnyy
# Processing Record 14 of Set 6 | highland
# Processing Record 15 of Set 6 | whitehorse
# Processing Record 16 of Set 6 | kruisfontein
# Processing Record 17 of Set 6 | aqadyr
# Processing Record 18 of Set 6 | san andres
# Processing Record 19 of Set 6 | saint-flour
# Processing Record 20 of Set 6 | arizona city
# Processing Record 21 of Set 6 | macau
# Processing Record 22 of Set 6 | kavieng
# Processing Record 23 of Set 6 | as sulayyil
# Processing Record 24 of Set 6 | ha'il
# Processing Record 25 of Set 6 | ebaye
# Processing Record 26 of Set 6 | gadzhiyevo
# Processing Record 27 of Set 6 | immokalee
# Processing Record 28 of Set 6 | monrovia
# Processing Record 29 of Set 6 | fukuecho
# Processing Record 30 of Set 6 | pandan
# Processing Record 31 of Set 6 | hennigsdorf
# Processing Record 32 of Set 6 | murzuq
# Processing Record 33 of Set 6 | richards bay
# Processing Record 34 of Set 6 | cam ranh
# Processing Record 35 of Set 6 | yuzhno-kurilsk
# Processing Record 36 of Set 6 | mandra
# Processing Record 37 of Set 6 | alo
# Processing Record 38 of Set 6 | saint-pierre
# Processing Record 39 of Set 6 | ketchikan
# Processing Record 40 of Set 6 | cidreira
# Processing Record 41 of Set 6 | egilsstadir
# Processing Record 42 of Set 6 | hithadhoo
# Processing Record 43 of Set 6 | zeya
# Processing Record 44 of Set 6 | forio
# Processing Record 45 of Set 6 | cargados carajos
# City not found. Skipping...
# Processing Record 46 of Set 6 | maitum
# Processing Record 47 of Set 6 | zapolyarnyy
# Processing Record 48 of Set 6 | porto novo
# Processing Record 49 of Set 6 | sao joao da barra
# Processing Record 0 of Set 7 | forbes
# Processing Record 1 of Set 7 | saratamata
# City not found. Skipping...
# Processing Record 2 of Set 7 | fort stockton
# Processing Record 3 of Set 7 | pontes e lacerda
# Processing Record 4 of Set 7 | katerini
# Processing Record 5 of Set 7 | madisonville
# Processing Record 6 of Set 7 | chai badan
# Processing Record 7 of Set 7 | el bauga
# Processing Record 8 of Set 7 | joinville
# Processing Record 9 of Set 7 | caleta de carquin
# Processing Record 10 of Set 7 | franklin
# Processing Record 11 of Set 7 | homestead meadows south
# Processing Record 12 of Set 7 | oriximina
# Processing Record 13 of Set 7 | kuanda
# Processing Record 14 of Set 7 | kangding
# Processing Record 15 of Set 7 | aykhal
# Processing Record 16 of Set 7 | sinan
# Processing Record 17 of Set 7 | dunedin
# Processing Record 18 of Set 7 | new norfolk
# Processing Record 19 of Set 7 | kapa'a
# Processing Record 20 of Set 7 | novo aripuana
# Processing Record 21 of Set 7 | prince rupert
# Processing Record 22 of Set 7 | dryden
# Processing Record 23 of Set 7 | san antonio de pale
# Processing Record 24 of Set 7 | chonchi
# Processing Record 25 of Set 7 | the pas
# Processing Record 26 of Set 7 | pedregal
# Processing Record 27 of Set 7 | mejit
# Processing Record 28 of Set 7 | bilibino
# Processing Record 29 of Set 7 | lauro de freitas
# Processing Record 30 of Set 7 | ahar
# Processing Record 31 of Set 7 | roma
# Processing Record 32 of Set 7 | atherton
# Processing Record 33 of Set 7 | wunsiedel
# Processing Record 34 of Set 7 | iquitos
# Processing Record 35 of Set 7 | buala
# Processing Record 36 of Set 7 | cairns city
# City not found. Skipping...
# Processing Record 37 of Set 7 | porto franco
# Processing Record 38 of Set 7 | kalianget
# Processing Record 39 of Set 7 | revelstoke
# Processing Record 40 of Set 7 | kalymnos
# Processing Record 41 of Set 7 | camarinas
# Processing Record 42 of Set 7 | kone
# Processing Record 43 of Set 7 | tawau
# Processing Record 44 of Set 7 | guerrero negro
# Processing Record 45 of Set 7 | bojnurd
# Processing Record 46 of Set 7 | plastun
# Processing Record 47 of Set 7 | jiuquan
# Processing Record 48 of Set 7 | san jose village
# City not found. Skipping...
# Processing Record 49 of Set 7 | revda
# Processing Record 0 of Set 8 | jinchang
# Processing Record 1 of Set 8 | klaksvik
# Processing Record 2 of Set 8 | barra do garcas
# Processing Record 3 of Set 8 | hamilton
# Processing Record 4 of Set 8 | rondonopolis
# Processing Record 5 of Set 8 | motueka
# Processing Record 6 of Set 8 | george town
# Processing Record 7 of Set 8 | tranovaho
# City not found. Skipping...
# Processing Record 8 of Set 8 | ola
# Processing Record 9 of Set 8 | kailua-kona
# Processing Record 10 of Set 8 | anabar
# City not found. Skipping...
# Processing Record 11 of Set 8 | playa del ingles
# Processing Record 12 of Set 8 | noumea
# Processing Record 13 of Set 8 | dhuusamarreeb
# Processing Record 14 of Set 8 | dadonghai
# City not found. Skipping...
# Processing Record 15 of Set 8 | krasavino
# Processing Record 16 of Set 8 | riti
# Processing Record 17 of Set 8 | francistown
# Processing Record 18 of Set 8 | tukums
# Processing Record 19 of Set 8 | nanao
# Processing Record 20 of Set 8 | la ronge
# Processing Record 21 of Set 8 | mersing
# Processing Record 22 of Set 8 | crane
# Processing Record 23 of Set 8 | kolwezi
# Processing Record 24 of Set 8 | panacan
# Processing Record 25 of Set 8 | sur
# Processing Record 26 of Set 8 | tazovsky
# Processing Record 27 of Set 8 | rabaul
# Processing Record 28 of Set 8 | saldanha
# Processing Record 29 of Set 8 | buncrana
# Processing Record 30 of Set 8 | tasqala
# Processing Record 31 of Set 8 | taulaga
# Processing Record 32 of Set 8 | brunico
# Processing Record 33 of Set 8 | boa vista
# Processing Record 34 of Set 8 | saint-joseph
# Processing Record 35 of Set 8 | balsas
# Processing Record 36 of Set 8 | padam
# City not found. Skipping...
# Processing Record 37 of Set 8 | la passe
# Processing Record 38 of Set 8 | aginskoye
# Processing Record 39 of Set 8 | belo sur tsiribihina
# Processing Record 40 of Set 8 | ta`u
# Processing Record 41 of Set 8 | filey
# Processing Record 42 of Set 8 | celestun
# Processing Record 43 of Set 8 | manavalakurichi
# Processing Record 44 of Set 8 | dolbeau-mistassini
# Processing Record 45 of Set 8 | sinabang
# Processing Record 46 of Set 8 | lospalos
# Processing Record 47 of Set 8 | al wakrah
# Processing Record 48 of Set 8 | tevriz
# Processing Record 49 of Set 8 | buenaventura
# Processing Record 0 of Set 9 | ancud
# Processing Record 1 of Set 9 | mana
# Processing Record 2 of Set 9 | cancale
# Processing Record 3 of Set 9 | mangaratiba
# Processing Record 4 of Set 9 | karnobat
# Processing Record 5 of Set 9 | st. john's
# Processing Record 6 of Set 9 | northam
# Processing Record 7 of Set 9 | alibag
# Processing Record 8 of Set 9 | jalasjarvi
# Processing Record 9 of Set 9 | kochubey
# Processing Record 10 of Set 9 | kasane
# Processing Record 11 of Set 9 | zhoukou
# Processing Record 12 of Set 9 | mount carmel
# Processing Record 13 of Set 9 | zaozersk
# Processing Record 14 of Set 9 | nizhnesortymskiy
# Processing Record 15 of Set 9 | santa ana
# Processing Record 16 of Set 9 | kijang
# Processing Record 17 of Set 9 | four corners
# Processing Record 18 of Set 9 | zalingei
# Processing Record 19 of Set 9 | portland
# Processing Record 20 of Set 9 | iranshahr
# Processing Record 21 of Set 9 | aleksandrovsk-sakhalinskiy
# Processing Record 22 of Set 9 | bondoukou
# Processing Record 23 of Set 9 | guarapari
# Processing Record 24 of Set 9 | cherlak
# Processing Record 25 of Set 9 | coquimbo
# Processing Record 26 of Set 9 | keflavik
# Processing Record 27 of Set 9 | tadine
# Processing Record 28 of Set 9 | bahia honda
# Processing Record 29 of Set 9 | luderitz
# Processing Record 30 of Set 9 | bubaque
# Processing Record 31 of Set 9 | ponta delgada
# Processing Record 32 of Set 9 | tanumah
# Processing Record 33 of Set 9 | burang
# Processing Record 34 of Set 9 | forshaga
# Processing Record 35 of Set 9 | san rafael del sur
# Processing Record 36 of Set 9 | glenvale
# Processing Record 37 of Set 9 | kroya
# Processing Record 38 of Set 9 | severo-yeniseyskiy
# Processing Record 39 of Set 9 | selfoss
# Processing Record 40 of Set 9 | berdigestyakh
# Processing Record 41 of Set 9 | craig
# Processing Record 42 of Set 9 | sitka
# Processing Record 43 of Set 9 | horta
# Processing Record 44 of Set 9 | murashi
# Processing Record 45 of Set 9 | severobaykal'sk
# Processing Record 46 of Set 9 | turpan
# Processing Record 47 of Set 9 | al 'aziziyah
# Processing Record 48 of Set 9 | balqash
# Processing Record 49 of Set 9 | salair
# Processing Record 0 of Set 10 | juye
# Processing Record 1 of Set 10 | al muwayh
# Processing Record 2 of Set 10 | ar ruways
# Processing Record 3 of Set 10 | cottonwood
# Processing Record 4 of Set 10 | chernyshevskiy
# Processing Record 5 of Set 10 | bologoye
# Processing Record 6 of Set 10 | sarikamis
# Processing Record 7 of Set 10 | merikanjaka
# City not found. Skipping...
# Processing Record 8 of Set 10 | norilsk
# Processing Record 9 of Set 10 | sharur city
# City not found. Skipping...
# Processing Record 10 of Set 10 | geraldton
# Processing Record 11 of Set 10 | weno
# Processing Record 12 of Set 10 | meadow lakes
# Processing Record 13 of Set 10 | juneau
# Processing Record 14 of Set 10 | tralee
# Processing Record 15 of Set 10 | el granada
# Processing Record 16 of Set 10 | vershino-darasunskiy
# Processing Record 17 of Set 10 | nadym
# Processing Record 18 of Set 10 | maubin
# Processing Record 19 of Set 10 | formosa do rio preto
# Processing Record 20 of Set 10 | boguchany
# Processing Record 21 of Set 10 | dar naim
# City not found. Skipping...
# Processing Record 22 of Set 10 | meulaboh
# Processing Record 23 of Set 10 | punta del este
# Processing Record 24 of Set 10 | thurso
# Processing Record 25 of Set 10 | mendoza
# Processing Record 26 of Set 10 | swellendam
# Processing Record 27 of Set 10 | priargunsk
# Processing Record 28 of Set 10 | port alberni
# Processing Record 29 of Set 10 | micheweni
# Processing Record 30 of Set 10 | falkenberg
# Processing Record 31 of Set 10 | patacamaya
# Processing Record 32 of Set 10 | batticaloa
# Processing Record 33 of Set 10 | donghai
# Processing Record 34 of Set 10 | kargasok
# Processing Record 35 of Set 10 | beyneu
# Processing Record 36 of Set 10 | laguna
# Processing Record 37 of Set 10 | darwin
# Processing Record 38 of Set 10 | monjaras
# Processing Record 39 of Set 10 | yerofey pavlovich
# Processing Record 40 of Set 10 | seydi
# Processing Record 41 of Set 10 | holualoa
# Processing Record 42 of Set 10 | bay roberts
# Processing Record 43 of Set 10 | waverly
# Processing Record 44 of Set 10 | dondo
# Processing Record 45 of Set 10 | jaguariaiva
# Processing Record 46 of Set 10 | destin
# Processing Record 47 of Set 10 | puerto san carlos
# City not found. Skipping...
# Processing Record 48 of Set 10 | peace river
# Processing Record 49 of Set 10 | morant bay
# Processing Record 0 of Set 11 | dampit
# Processing Record 1 of Set 11 | andilamena
# Processing Record 2 of Set 11 | newman
# Processing Record 3 of Set 11 | buka
# Processing Record 4 of Set 11 | manokwari
# Processing Record 5 of Set 11 | gnesta
# Processing Record 6 of Set 11 | ujae
# Processing Record 7 of Set 11 | alaghsas
# Processing Record 8 of Set 11 | el calafate
# Processing Record 9 of Set 11 | freetown
# Processing Record 10 of Set 11 | korla
# Processing Record 11 of Set 11 | aur
# Processing Record 12 of Set 11 | show low
# Processing Record 13 of Set 11 | kudahuvadhoo
# Processing Record 14 of Set 11 | shimoda
# Processing Record 15 of Set 11 | la'ie
# Processing Record 16 of Set 11 | parambu
# Processing Record 17 of Set 11 | elliot
# Processing Record 18 of Set 11 | carandai
# Processing Record 19 of Set 11 | dongcun
# Processing Record 20 of Set 11 | mochudi
# Processing Record 21 of Set 11 | djibo
# Processing Record 22 of Set 11 | tara
# Processing Record 23 of Set 11 | scottsboro
# Processing Record 24 of Set 11 | fort st. john
# Processing Record 25 of Set 11 | kalat
# Processing Record 26 of Set 11 | ciudad lazaro cardenas
# Processing Record 27 of Set 11 | am djarass
# City not found. Skipping...
# Processing Record 28 of Set 11 | kerikeri
# Processing Record 29 of Set 11 | white hall
# Processing Record 30 of Set 11 | karangampel
# Processing Record 31 of Set 11 | whitby
# Processing Record 32 of Set 11 | maues
# Processing Record 33 of Set 11 | tangalle
# Processing Record 34 of Set 11 | madera
# Processing Record 35 of Set 11 | tazacorte
# Processing Record 36 of Set 11 | urangan
# Processing Record 37 of Set 11 | nova xavantina
# Processing Record 38 of Set 11 | aljezur
# Processing Record 39 of Set 11 | ulsteinvik
# Processing Record 40 of Set 11 | ati
# Processing Record 41 of Set 11 | ambon
# Processing Record 42 of Set 11 | corner brook
# Processing Record 43 of Set 11 | sirte
# Processing Record 44 of Set 11 | itoman
# Processing Record 45 of Set 11 | orkney
# Processing Record 46 of Set 11 | trinidad
# Processing Record 47 of Set 11 | ciudad guayana
# Processing Record 48 of Set 11 | jokioinen
# Processing Record 49 of Set 11 | shendi
# Processing Record 0 of Set 12 | namibe
# Processing Record 1 of Set 12 | muisne
# Processing Record 2 of Set 12 | toga village
# City not found. Skipping...
# Processing Record 3 of Set 12 | nantucket
# Processing Record 4 of Set 12 | frontera corozal
# City not found. Skipping...
# Processing Record 5 of Set 12 | arno
# Processing Record 6 of Set 12 | cascais
# Processing Record 7 of Set 12 | dili
# Processing Record 8 of Set 12 | floro
# Processing Record 9 of Set 12 | qusmuryn
# Processing Record 10 of Set 12 | yujing
# Processing Record 11 of Set 12 | lucija
# Processing Record 12 of Set 12 | wuhai
# Processing Record 13 of Set 12 | alto araguaia
# Processing Record 14 of Set 12 | warrnambool
# Processing Record 15 of Set 12 | robertsport
# Processing Record 16 of Set 12 | murmansk
# Processing Record 17 of Set 12 | sol'-iletsk
# Processing Record 18 of Set 12 | sarangani
# Processing Record 19 of Set 12 | hoemul-li
# Processing Record 20 of Set 12 | karumbakkam
# Processing Record 21 of Set 12 | khovd
# Processing Record 22 of Set 12 | gowurdak
# Processing Record 23 of Set 12 | fuding
# Processing Record 24 of Set 12 | amphoe sikhiu
# Processing Record 25 of Set 12 | forster
# Processing Record 26 of Set 12 | susuman
# Processing Record 27 of Set 12 | swan hill
# Processing Record 28 of Set 12 | angaur state
# Processing Record 29 of Set 12 | turochak
# Processing Record 30 of Set 12 | howard springs
# Processing Record 31 of Set 12 | polyarnyy
# Processing Record 32 of Set 12 | sijunjung
# Processing Record 33 of Set 12 | poronaysk
# Processing Record 34 of Set 12 | motygino
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          555
# Lat           555
# Lng           555
# Max Temp      555
# Humidity      555
# Cloudiness    555
# Wind Speed    555
# Country       555
# Date          555
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          adamstown -25.0660 -130.1015     67.59        76          91
# 1       puerto ayora  -0.7393  -90.3518     76.10        85          51
# 2          vorgashor  67.5833   63.9500     71.91        50          46
# 3             kodiak  57.7900 -152.4072     47.71        93           0
# 4  port-aux-francais -49.3500   70.2167     41.72        91         100
#
#    Wind Speed Country        Date
# 0       16.87      PN  1690197234
# 1        7.74      EC  1690197274
# 2        5.53      RU  1690197274
# 3        4.61      US  1690197274
# 4       32.08      TF  1690197234

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                adamstown -25.0660 -130.1015     67.59        76          91
# 1             puerto ayora  -0.7393  -90.3518     76.10        85          51
# 2                vorgashor  67.5833   63.9500     71.91        50          46
# 3                   kodiak  57.7900 -152.4072     47.71        93           0
# 4        port-aux-francais -49.3500   70.2167     41.72        91         100
#
#          Wind Speed Country        Date
# City_ID
# 0             16.87      PN  1690197234
# 1              7.74      EC  1690197274
# 2              5.53      RU  1690197274
# 3              4.61      US  1690197274
# 4             32.08      TF  1690197234

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker = 'o', edgecolor="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker = 'o', edgecolor="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], marker = 'o')

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt. grid(True)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], marker = 'o')


# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
#####LAT VS. TEMP#####
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20, 30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title('Latitude vs. Max Temp')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.013499757735673848

# %%
# Define a function to create Linear Regression plots
#####LAT VS. HUMIDITY#####
x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Latitude vs. Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.00012351480526362577

# %%
# Define a function to create Linear Regression plots
#####LAT VS. CLOUDINESS#####
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Latitude vs. Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.010127985059507419

# %%
# Define a function to create Linear Regression plots
#####LAT VS. WIND SPEED#####
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Latitude vs. Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0060479364764627185

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2          vorgashor  67.5833   63.9500     71.91        50          46
# 3             kodiak  57.7900 -152.4072     47.71        93           0
# 5        kapuskasing  49.4169  -82.4331     50.09        93          20
# 8          iskateley  67.6803   53.1512     68.45        63          96
# 10         jamestown  42.0970  -79.2353     65.79        99          40
#
#          Wind Speed Country        Date
# City_ID
# 2              5.53      RU  1690197274
# 3              4.61      US  1690197274
# 5              2.30      CA  1690197274
# 8             12.82      RU  1690197274
# 10             5.75      US  1690197220

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                adamstown -25.0660 -130.1015     67.59        76          91
# 1             puerto ayora  -0.7393  -90.3518     76.10        85          51
# 4        port-aux-francais -49.3500   70.2167     41.72        91         100
# 6             invercargill -46.4000  168.3500     47.23        91          97
# 7                  ushuaia -54.8000  -68.3000     26.26        80           0
#
#          Wind Speed Country        Date
# City_ID
# 0             16.87      PN  1690197234
# 1              7.74      EC  1690197274
# 4             32.08      TF  1690197234
# 6              5.91      NZ  1690197274
# 7              3.44      AR  1690197242

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title('Latitude vs. Max Temp')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.34638206900072965

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title('Latitude vs. Max Temp')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7038209915609097

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Latitude vs. Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0005332388643182598

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Latitude vs. Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.010415120844586259

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Latitude vs. Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 1.1844143974839052e-05

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.03928793661462996

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, color="red")
plt.annotate(line_eq,(-20,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Latitude vs. Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.015927297721208964

# %%
# Southern Hemisphere

x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, color="red")
plt.annotate(line_eq,(-20,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Latitude vs. Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.007948326723322794

# %% [markdown]
# **Discussion about the linear relationship:** the r-value suggests that there is a weak negative correlation between latitude and wind speed in the southern hemisphere
