# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 634

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city

    city_url = f"{url}&q={city}"
    #print(city_url)
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]


        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bilibino
# Processing Record 2 of Set 1 | lambarene
# Processing Record 3 of Set 1 | olonkinbyen
# Processing Record 4 of Set 1 | ash shihaniyah
# Processing Record 5 of Set 1 | quilmana
# Processing Record 6 of Set 1 | harrison
# Processing Record 7 of Set 1 | boa vista
# Processing Record 8 of Set 1 | qaqortoq
# Processing Record 9 of Set 1 | albert lea
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | nuuk
# Processing Record 12 of Set 1 | fuvahmulah
# City not found. Skipping...
# Processing Record 13 of Set 1 | adamstown
# Processing Record 14 of Set 1 | whitehorse
# Processing Record 15 of Set 1 | chonchi
# Processing Record 16 of Set 1 | vorgashor
# Processing Record 17 of Set 1 | port-aux-francais
# Processing Record 18 of Set 1 | alice springs
# Processing Record 19 of Set 1 | tommot
# Processing Record 20 of Set 1 | port alfred
# Processing Record 21 of Set 1 | san luis de la loma
# Processing Record 22 of Set 1 | linhares
# Processing Record 23 of Set 1 | katima mulilo
# Processing Record 24 of Set 1 | castillos
# Processing Record 25 of Set 1 | cabedelo
# Processing Record 26 of Set 1 | dudinka
# Processing Record 27 of Set 1 | galliano
# Processing Record 28 of Set 1 | loango
# Processing Record 29 of Set 1 | lompoc
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | blackmans bay
# Processing Record 32 of Set 1 | carnarvon
# Processing Record 33 of Set 1 | tiksi
# Processing Record 34 of Set 1 | trinity beach
# Processing Record 35 of Set 1 | nova sintra
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | san antonio de pale
# Processing Record 38 of Set 1 | new norfolk
# Processing Record 39 of Set 1 | severo-yeniseyskiy
# Processing Record 40 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 41 of Set 1 | gilgit
# Processing Record 42 of Set 1 | fuxin
# Processing Record 43 of Set 1 | nukunonu
# City not found. Skipping...
# Processing Record 44 of Set 1 | igarka
# Processing Record 45 of Set 1 | happy valley-goose bay
# Processing Record 46 of Set 1 | tobelo
# Processing Record 47 of Set 1 | stanley
# Processing Record 48 of Set 1 | waitangi
# Processing Record 49 of Set 1 | safi
# Processing Record 50 of Set 1 | kapa'a
# Processing Record 0 of Set 2 | klyuchi
# Processing Record 1 of Set 2 | bawshar
# Processing Record 2 of Set 2 | hermanus
# Processing Record 3 of Set 2 | clarksdale
# Processing Record 4 of Set 2 | edinburgh of the seven seas
# Processing Record 5 of Set 2 | bredasdorp
# Processing Record 6 of Set 2 | usakos
# Processing Record 7 of Set 2 | souillac
# Processing Record 8 of Set 2 | totness
# Processing Record 9 of Set 2 | lamu
# Processing Record 10 of Set 2 | papatowai
# Processing Record 11 of Set 2 | westport
# Processing Record 12 of Set 2 | howrah
# Processing Record 13 of Set 2 | el calafate
# Processing Record 14 of Set 2 | longyearbyen
# Processing Record 15 of Set 2 | howard springs
# Processing Record 16 of Set 2 | ust-nera
# Processing Record 17 of Set 2 | hawaiian paradise park
# Processing Record 18 of Set 2 | la passe
# Processing Record 19 of Set 2 | saurimo
# Processing Record 20 of Set 2 | west end
# Processing Record 21 of Set 2 | south boston
# Processing Record 22 of Set 2 | georgetown
# Processing Record 23 of Set 2 | ribeira grande
# Processing Record 24 of Set 2 | grytviken
# Processing Record 25 of Set 2 | kiunga
# Processing Record 26 of Set 2 | motygino
# Processing Record 27 of Set 2 | jamestown
# Processing Record 28 of Set 2 | aasiaat
# Processing Record 29 of Set 2 | port elizabeth
# Processing Record 30 of Set 2 | puerto natales
# Processing Record 31 of Set 2 | ambarakaraka
# City not found. Skipping...
# Processing Record 32 of Set 2 | thompson
# Processing Record 33 of Set 2 | saratamata
# City not found. Skipping...
# Processing Record 34 of Set 2 | kerrville
# Processing Record 35 of Set 2 | albany
# Processing Record 36 of Set 2 | stephenville
# Processing Record 37 of Set 2 | saint-pierre
# Processing Record 38 of Set 2 | fort william
# Processing Record 39 of Set 2 | college
# Processing Record 40 of Set 2 | wailua homesteads
# Processing Record 41 of Set 2 | sitia
# Processing Record 42 of Set 2 | tari
# Processing Record 43 of Set 2 | broome
# Processing Record 44 of Set 2 | chibougamau
# Processing Record 45 of Set 2 | uturoa
# Processing Record 46 of Set 2 | dazuocun
# Processing Record 47 of Set 2 | invercargill
# Processing Record 48 of Set 2 | rongelap
# Processing Record 49 of Set 2 | vilyuchinsk
# Processing Record 0 of Set 3 | san patricio
# Processing Record 1 of Set 3 | illizi
# Processing Record 2 of Set 3 | ulsteinvik
# Processing Record 3 of Set 3 | margaret river
# Processing Record 4 of Set 3 | kailua-kona
# Processing Record 5 of Set 3 | kristiansund
# Processing Record 6 of Set 3 | daru
# Processing Record 7 of Set 3 | mili
# Processing Record 8 of Set 3 | harwich
# Processing Record 9 of Set 3 | shagonar
# Processing Record 10 of Set 3 | qal'at bishah
# City not found. Skipping...
# Processing Record 11 of Set 3 | ilulissat
# Processing Record 12 of Set 3 | dausa
# Processing Record 13 of Set 3 | kalinkavichy
# Processing Record 14 of Set 3 | puerto deseado
# Processing Record 15 of Set 3 | avarua
# Processing Record 16 of Set 3 | sur
# Processing Record 17 of Set 3 | geraldton
# Processing Record 18 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 19 of Set 3 | susuman
# Processing Record 20 of Set 3 | gadzhiyevo
# Processing Record 21 of Set 3 | stornoway
# Processing Record 22 of Set 3 | ribeira brava
# Processing Record 23 of Set 3 | sonoita
# Processing Record 24 of Set 3 | coalinga
# Processing Record 25 of Set 3 | nieuw amsterdam
# Processing Record 26 of Set 3 | okhotsk
# Processing Record 27 of Set 3 | ventersburg
# Processing Record 28 of Set 3 | fort-shevchenko
# Processing Record 29 of Set 3 | sudzha
# Processing Record 30 of Set 3 | mhamid
# Processing Record 31 of Set 3 | taibet
# City not found. Skipping...
# Processing Record 32 of Set 3 | tura
# Processing Record 33 of Set 3 | waddan
# Processing Record 34 of Set 3 | nemuro
# Processing Record 35 of Set 3 | saipan
# Processing Record 36 of Set 3 | labytnangi
# Processing Record 37 of Set 3 | santa catalina
# Processing Record 38 of Set 3 | torit
# Processing Record 39 of Set 3 | san angelo
# Processing Record 40 of Set 3 | jiuquan
# Processing Record 41 of Set 3 | kodiak
# Processing Record 42 of Set 3 | west island
# Processing Record 43 of Set 3 | kyabe
# Processing Record 44 of Set 3 | jijel
# Processing Record 45 of Set 3 | bethel
# Processing Record 46 of Set 3 | isafjordur
# Processing Record 47 of Set 3 | mufumbwe
# Processing Record 48 of Set 3 | undurkhaan
# Processing Record 49 of Set 3 | puerto varas
# Processing Record 0 of Set 4 | nar'yan-mar
# Processing Record 1 of Set 4 | cidreira
# Processing Record 2 of Set 4 | north platte
# Processing Record 3 of Set 4 | atasu
# Processing Record 4 of Set 4 | cody
# Processing Record 5 of Set 4 | usinsk
# Processing Record 6 of Set 4 | brigantine
# Processing Record 7 of Set 4 | nguigmi
# Processing Record 8 of Set 4 | ingeniero guillermo n. juarez
# Processing Record 9 of Set 4 | cabo san lucas
# Processing Record 10 of Set 4 | talnakh
# Processing Record 11 of Set 4 | taulaga
# Processing Record 12 of Set 4 | al wafrah
# Processing Record 13 of Set 4 | codrington
# Processing Record 14 of Set 4 | lihue
# Processing Record 15 of Set 4 | am djarass
# City not found. Skipping...
# Processing Record 16 of Set 4 | alamosa
# Processing Record 17 of Set 4 | santo antonio do ica
# Processing Record 18 of Set 4 | ulladulla
# Processing Record 19 of Set 4 | ciudad lazaro cardenas
# Processing Record 20 of Set 4 | quellon
# Processing Record 21 of Set 4 | yarkovo
# Processing Record 22 of Set 4 | lata
# Processing Record 23 of Set 4 | pantai cenang
# City not found. Skipping...
# Processing Record 24 of Set 4 | port lincoln
# Processing Record 25 of Set 4 | waingapu
# Processing Record 26 of Set 4 | palmira
# Processing Record 27 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 28 of Set 4 | atar
# Processing Record 29 of Set 4 | iquique
# Processing Record 30 of Set 4 | iqaluit
# Processing Record 31 of Set 4 | tofol
# Processing Record 32 of Set 4 | basoko
# Processing Record 33 of Set 4 | es castell
# Processing Record 34 of Set 4 | awjilah
# Processing Record 35 of Set 4 | santiago de cao
# Processing Record 36 of Set 4 | bandarbeyla
# Processing Record 37 of Set 4 | harper
# Processing Record 38 of Set 4 | barro alto
# Processing Record 39 of Set 4 | murun-kuren
# Processing Record 40 of Set 4 | queenstown
# Processing Record 41 of Set 4 | salalah
# Processing Record 42 of Set 4 | callao
# Processing Record 43 of Set 4 | carolina beach
# Processing Record 44 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 45 of Set 4 | as sulayyil
# Processing Record 46 of Set 4 | marsabit
# Processing Record 47 of Set 4 | el gouna
# Processing Record 48 of Set 4 | obidos
# Processing Record 49 of Set 4 | sayat
# Processing Record 0 of Set 5 | prince rupert
# Processing Record 1 of Set 5 | hami
# Processing Record 2 of Set 5 | fuyu
# Processing Record 3 of Set 5 | saint-philippe
# Processing Record 4 of Set 5 | hasaki
# Processing Record 5 of Set 5 | lujan
# Processing Record 6 of Set 5 | anadyr
# Processing Record 7 of Set 5 | santana
# Processing Record 8 of Set 5 | monahans
# Processing Record 9 of Set 5 | greenfield
# Processing Record 10 of Set 5 | hithadhoo
# Processing Record 11 of Set 5 | tual
# Processing Record 12 of Set 5 | coquimbo
# Processing Record 13 of Set 5 | den burg
# Processing Record 14 of Set 5 | luderitz
# Processing Record 15 of Set 5 | bilajer
# Processing Record 16 of Set 5 | tinana
# City not found. Skipping...
# Processing Record 17 of Set 5 | bouna
# Processing Record 18 of Set 5 | kendari
# Processing Record 19 of Set 5 | lazaro cardenas
# Processing Record 20 of Set 5 | la'ie
# Processing Record 21 of Set 5 | mejit
# Processing Record 22 of Set 5 | ourilandia do norte
# City not found. Skipping...
# Processing Record 23 of Set 5 | starodub
# Processing Record 24 of Set 5 | huarmey
# Processing Record 25 of Set 5 | utrik
# Processing Record 26 of Set 5 | holualoa
# Processing Record 27 of Set 5 | sechura
# Processing Record 28 of Set 5 | itaituba
# Processing Record 29 of Set 5 | hayma'
# City not found. Skipping...
# Processing Record 30 of Set 5 | dosso
# Processing Record 31 of Set 5 | salekhard
# Processing Record 32 of Set 5 | belmonte
# Processing Record 33 of Set 5 | manokwari
# Processing Record 34 of Set 5 | grand gaube
# Processing Record 35 of Set 5 | egilsstadir
# Processing Record 36 of Set 5 | kismayo
# Processing Record 37 of Set 5 | karatuzskoye
# Processing Record 38 of Set 5 | choibalsan
# Processing Record 39 of Set 5 | arraial do cabo
# Processing Record 40 of Set 5 | hamilton
# Processing Record 41 of Set 5 | kerman
# Processing Record 42 of Set 5 | robore
# Processing Record 43 of Set 5 | newman
# Processing Record 44 of Set 5 | ares
# Processing Record 45 of Set 5 | i-n-salah
# Processing Record 46 of Set 5 | lensk
# Processing Record 47 of Set 5 | aykhal
# Processing Record 48 of Set 5 | alofi
# Processing Record 49 of Set 5 | sinabang
# Processing Record 0 of Set 6 | yellowknife
# Processing Record 1 of Set 6 | rome
# Processing Record 2 of Set 6 | pedra branca
# Processing Record 3 of Set 6 | narok
# Processing Record 4 of Set 6 | amos
# Processing Record 5 of Set 6 | kangding
# Processing Record 6 of Set 6 | tazovsky
# Processing Record 7 of Set 6 | tralee
# Processing Record 8 of Set 6 | kidal
# Processing Record 9 of Set 6 | gaspe
# Processing Record 10 of Set 6 | udachny
# Processing Record 11 of Set 6 | bemidji
# Processing Record 12 of Set 6 | badger
# Processing Record 13 of Set 6 | marietta
# Processing Record 14 of Set 6 | saint-leu
# Processing Record 15 of Set 6 | suileng
# Processing Record 16 of Set 6 | constantia
# Processing Record 17 of Set 6 | 'ohonua
# City not found. Skipping...
# Processing Record 18 of Set 6 | manaure
# Processing Record 19 of Set 6 | luganville
# Processing Record 20 of Set 6 | kralendijk
# Processing Record 21 of Set 6 | bardai
# Processing Record 22 of Set 6 | morondava
# Processing Record 23 of Set 6 | sinan
# Processing Record 24 of Set 6 | kone
# Processing Record 25 of Set 6 | acajutla
# Processing Record 26 of Set 6 | praia
# Processing Record 27 of Set 6 | male
# Processing Record 28 of Set 6 | saint george's
# Processing Record 29 of Set 6 | dickson
# Processing Record 30 of Set 6 | enewetak
# Processing Record 31 of Set 6 | nabire
# Processing Record 32 of Set 6 | siocon
# Processing Record 33 of Set 6 | sao felix do xingu
# Processing Record 34 of Set 6 | port mathurin
# Processing Record 35 of Set 6 | khandyga
# Processing Record 36 of Set 6 | tolanaro
# Processing Record 37 of Set 6 | yeniseysk
# Processing Record 38 of Set 6 | taltal
# Processing Record 39 of Set 6 | entebbe
# Processing Record 40 of Set 6 | qamdo
# Processing Record 41 of Set 6 | argos
# Processing Record 42 of Set 6 | kavieng
# Processing Record 43 of Set 6 | devinuwara
# City not found. Skipping...
# Processing Record 44 of Set 6 | san nicolas
# Processing Record 45 of Set 6 | ponoka
# Processing Record 46 of Set 6 | tsawwassen
# Processing Record 47 of Set 6 | xilin hot
# Processing Record 48 of Set 6 | pizarro
# Processing Record 49 of Set 6 | sambava
# Processing Record 0 of Set 7 | korla
# Processing Record 1 of Set 7 | rio grande
# Processing Record 2 of Set 7 | muli
# Processing Record 3 of Set 7 | kurumkan
# Processing Record 4 of Set 7 | vredendal
# Processing Record 5 of Set 7 | mata-utu
# Processing Record 6 of Set 7 | atafu village
# Processing Record 7 of Set 7 | sitka
# Processing Record 8 of Set 7 | catalina
# Processing Record 9 of Set 7 | mitchell
# Processing Record 10 of Set 7 | levuka
# Processing Record 11 of Set 7 | fale old settlement
# Processing Record 12 of Set 7 | morehead city
# Processing Record 13 of Set 7 | dera bugti
# Processing Record 14 of Set 7 | viedma
# Processing Record 15 of Set 7 | fort bragg
# Processing Record 16 of Set 7 | inirida
# Processing Record 17 of Set 7 | tukrah
# Processing Record 18 of Set 7 | puerto baquerizo moreno
# Processing Record 19 of Set 7 | turpan
# Processing Record 20 of Set 7 | praia da vitoria
# Processing Record 21 of Set 7 | waiuku
# Processing Record 22 of Set 7 | yamethin
# Processing Record 23 of Set 7 | hobyo
# Processing Record 24 of Set 7 | fortuna
# Processing Record 25 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 26 of Set 7 | chui
# Processing Record 27 of Set 7 | laascaanood
# Processing Record 28 of Set 7 | lerwick
# Processing Record 29 of Set 7 | oranjemund
# Processing Record 30 of Set 7 | ongjin
# Processing Record 31 of Set 7 | aswan
# Processing Record 32 of Set 7 | lebu
# Processing Record 33 of Set 7 | jijiga
# Processing Record 34 of Set 7 | santyoku
# Processing Record 35 of Set 7 | ca mau
# Processing Record 36 of Set 7 | tamiahua
# Processing Record 37 of Set 7 | ceres
# Processing Record 38 of Set 7 | dawesville
# Processing Record 39 of Set 7 | kampene
# Processing Record 40 of Set 7 | hadibu
# Processing Record 41 of Set 7 | saldanha
# Processing Record 42 of Set 7 | nikolayevsk-on-amure
# Processing Record 43 of Set 7 | portland
# Processing Record 44 of Set 7 | macedo de cavaleiros
# Processing Record 45 of Set 7 | amarpatan
# Processing Record 46 of Set 7 | miquelon
# Processing Record 47 of Set 7 | acapulco de juarez
# Processing Record 48 of Set 7 | urangan
# Processing Record 49 of Set 7 | palikir - national government center
# Processing Record 0 of Set 8 | agadez
# Processing Record 1 of Set 8 | ghat
# Processing Record 2 of Set 8 | rubizhne
# Processing Record 3 of Set 8 | urengoy
# Processing Record 4 of Set 8 | minas de marcona
# Processing Record 5 of Set 8 | bretten
# Processing Record 6 of Set 8 | tucumcari
# Processing Record 7 of Set 8 | posto fiscal rolim de moura
# Processing Record 8 of Set 8 | padang
# Processing Record 9 of Set 8 | tanjung pandan
# Processing Record 10 of Set 8 | gambat
# Processing Record 11 of Set 8 | pamekasan
# Processing Record 12 of Set 8 | page
# Processing Record 13 of Set 8 | manston
# Processing Record 14 of Set 8 | dryden
# Processing Record 15 of Set 8 | darwin
# Processing Record 16 of Set 8 | conception bay south
# Processing Record 17 of Set 8 | mumbwa
# Processing Record 18 of Set 8 | las animas
# Processing Record 19 of Set 8 | makoua
# Processing Record 20 of Set 8 | inekar
# City not found. Skipping...
# Processing Record 21 of Set 8 | ritchie
# Processing Record 22 of Set 8 | el bauga
# Processing Record 23 of Set 8 | gornopravdinsk
# Processing Record 24 of Set 8 | macapa
# Processing Record 25 of Set 8 | itamaraju
# Processing Record 26 of Set 8 | mgandu
# Processing Record 27 of Set 8 | kerema
# Processing Record 28 of Set 8 | sabinanigo
# Processing Record 29 of Set 8 | kingston
# Processing Record 30 of Set 8 | chrysoupolis
# Processing Record 31 of Set 8 | palmer
# Processing Record 32 of Set 8 | nyurba
# Processing Record 33 of Set 8 | taoudenni
# Processing Record 34 of Set 8 | tazacorte
# Processing Record 35 of Set 8 | kvissleby
# Processing Record 36 of Set 8 | bintulu
# Processing Record 37 of Set 8 | vadso
# Processing Record 38 of Set 8 | chiras
# Processing Record 39 of Set 8 | usogorsk
# Processing Record 40 of Set 8 | keflavik
# Processing Record 41 of Set 8 | qarqaraly
# Processing Record 42 of Set 8 | tranovaho
# City not found. Skipping...
# Processing Record 43 of Set 8 | forbes
# Processing Record 44 of Set 8 | preobrazheniye
# Processing Record 45 of Set 8 | marienthal
# Processing Record 46 of Set 8 | guanica
# Processing Record 47 of Set 8 | sogndal
# Processing Record 48 of Set 8 | funafuti
# Processing Record 49 of Set 8 | stilfontein
# Processing Record 0 of Set 9 | coron
# Processing Record 1 of Set 9 | calabozo
# Processing Record 2 of Set 9 | danane
# Processing Record 3 of Set 9 | camayenne
# Processing Record 4 of Set 9 | quiberon
# Processing Record 5 of Set 9 | ghanzi
# Processing Record 6 of Set 9 | dunedin
# Processing Record 7 of Set 9 | althengstett
# Processing Record 8 of Set 9 | nagano
# Processing Record 9 of Set 9 | lalibela
# Processing Record 10 of Set 9 | ierapetra
# Processing Record 11 of Set 9 | soe
# Processing Record 12 of Set 9 | la gomera
# Processing Record 13 of Set 9 | kayangel
# Processing Record 14 of Set 9 | ambon
# Processing Record 15 of Set 9 | mahina
# Processing Record 16 of Set 9 | labrador city
# Processing Record 17 of Set 9 | st. john's
# Processing Record 18 of Set 9 | rio gallegos
# Processing Record 19 of Set 9 | puerto aysen
# Processing Record 20 of Set 9 | touros
# Processing Record 21 of Set 9 | east london
# Processing Record 22 of Set 9 | santa ana de yacuma
# Processing Record 23 of Set 9 | santa elena de uairen
# Processing Record 24 of Set 9 | rio verde de mato grosso
# Processing Record 25 of Set 9 | vingt cinq
# City not found. Skipping...
# Processing Record 26 of Set 9 | shevchenko
# Processing Record 27 of Set 9 | mount gambier
# Processing Record 28 of Set 9 | mandera
# Processing Record 29 of Set 9 | bayan nur
# City not found. Skipping...
# Processing Record 30 of Set 9 | tsiombe
# Processing Record 31 of Set 9 | remire-montjoly
# Processing Record 32 of Set 9 | isangel
# Processing Record 33 of Set 9 | champerico
# Processing Record 34 of Set 9 | haiku-pauwela
# Processing Record 35 of Set 9 | 'ain benian
# Processing Record 36 of Set 9 | international falls
# Processing Record 37 of Set 9 | afaahiti
# Processing Record 38 of Set 9 | asau
# Processing Record 39 of Set 9 | olyokminsk
# Processing Record 40 of Set 9 | vila franca do campo
# Processing Record 41 of Set 9 | ebon
# Processing Record 42 of Set 9 | puerto san carlos
# City not found. Skipping...
# Processing Record 43 of Set 9 | yaren
# Processing Record 44 of Set 9 | ishinomaki
# Processing Record 45 of Set 9 | port macquarie
# Processing Record 46 of Set 9 | uray
# Processing Record 47 of Set 9 | fort mcmurray
# Processing Record 48 of Set 9 | boyolangu
# Processing Record 49 of Set 9 | squamish
# Processing Record 0 of Set 10 | murzuq
# Processing Record 1 of Set 10 | christchurch
# Processing Record 2 of Set 10 | parksville
# Processing Record 3 of Set 10 | karratha
# Processing Record 4 of Set 10 | zeya
# Processing Record 5 of Set 10 | kolaras
# Processing Record 6 of Set 10 | samraong
# Processing Record 7 of Set 10 | lijiang
# Processing Record 8 of Set 10 | salumbar
# Processing Record 9 of Set 10 | concepcion de la sierra
# Processing Record 10 of Set 10 | puerto la cruz
# Processing Record 11 of Set 10 | laguna
# Processing Record 12 of Set 10 | sebastopol
# Processing Record 13 of Set 10 | mount pearl
# Processing Record 14 of Set 10 | argo
# Processing Record 15 of Set 10 | bamboo flat
# Processing Record 16 of Set 10 | flin flon
# Processing Record 17 of Set 10 | amahai
# Processing Record 18 of Set 10 | aktau
# Processing Record 19 of Set 10 | ugoofaaru
# Processing Record 20 of Set 10 | ostersund
# Processing Record 21 of Set 10 | patamda
# Processing Record 22 of Set 10 | freetown
# Processing Record 23 of Set 10 | cannonvale
# Processing Record 24 of Set 10 | micheweni
# Processing Record 25 of Set 10 | crane
# Processing Record 26 of Set 10 | collie
# Processing Record 27 of Set 10 | brokopondo
# Processing Record 28 of Set 10 | malango
# Processing Record 29 of Set 10 | timaru
# Processing Record 30 of Set 10 | yunyang
# Processing Record 31 of Set 10 | orange
# Processing Record 32 of Set 10 | batie
# Processing Record 33 of Set 10 | tottori
# Processing Record 34 of Set 10 | polyarnyy
# Processing Record 35 of Set 10 | lesozavodsk
# Processing Record 36 of Set 10 | nkurenkuru
# City not found. Skipping...
# Processing Record 37 of Set 10 | conde
# Processing Record 38 of Set 10 | kinablangan
# Processing Record 39 of Set 10 | isla cristina
# Processing Record 40 of Set 10 | santo antonio
# Processing Record 41 of Set 10 | forster
# Processing Record 42 of Set 10 | trairi
# Processing Record 43 of Set 10 | makurazaki
# Processing Record 44 of Set 10 | trevelin
# Processing Record 45 of Set 10 | sarmiento
# Processing Record 46 of Set 10 | pirot
# Processing Record 47 of Set 10 | ust'-ilimsk
# Processing Record 48 of Set 10 | morant bay
# Processing Record 49 of Set 10 | cadale
# Processing Record 0 of Set 11 | wad rawah
# Processing Record 1 of Set 11 | shingu
# Processing Record 2 of Set 11 | ouellah
# City not found. Skipping...
# Processing Record 3 of Set 11 | knyaze-volkonskoye
# Processing Record 4 of Set 11 | takamaka
# City not found. Skipping...
# Processing Record 5 of Set 11 | ilabaya
# Processing Record 6 of Set 11 | vyritsa
# Processing Record 7 of Set 11 | erenhot
# Processing Record 8 of Set 11 | fortuna foothills
# Processing Record 9 of Set 11 | saint-francois
# Processing Record 10 of Set 11 | aliveri
# Processing Record 11 of Set 11 | campo gallo
# Processing Record 12 of Set 11 | elmendorf air force base
# City not found. Skipping...
# Processing Record 13 of Set 11 | olinda
# Processing Record 14 of Set 11 | priozersk
# Processing Record 15 of Set 11 | soledad
# Processing Record 16 of Set 11 | sarh
# Processing Record 17 of Set 11 | ormara
# Processing Record 18 of Set 11 | nagqu
# Processing Record 19 of Set 11 | lutes mountain
# City not found. Skipping...
# Processing Record 20 of Set 11 | ayorou
# Processing Record 21 of Set 11 | bossangoa
# Processing Record 22 of Set 11 | sindhnur
# Processing Record 23 of Set 11 | strelka
# Processing Record 24 of Set 11 | miyako
# Processing Record 25 of Set 11 | mariehamn
# Processing Record 26 of Set 11 | greymouth
# Processing Record 27 of Set 11 | mar del plata
# Processing Record 28 of Set 11 | port augusta
# Processing Record 29 of Set 11 | semporna
# Processing Record 30 of Set 11 | puerto maldonado
# Processing Record 31 of Set 11 | glace bay
# Processing Record 32 of Set 11 | wynyard
# Processing Record 33 of Set 11 | axim
# Processing Record 34 of Set 11 | whitby
# Processing Record 35 of Set 11 | zangguy
# City not found. Skipping...
# Processing Record 36 of Set 11 | les cayes
# Processing Record 37 of Set 11 | tres isletas
# Processing Record 38 of Set 11 | childress
# Processing Record 39 of Set 11 | tosontsengel
# Processing Record 40 of Set 11 | jose mariano jimenez
# City not found. Skipping...
# Processing Record 41 of Set 11 | lakatoro
# Processing Record 42 of Set 11 | vila velha
# Processing Record 43 of Set 11 | yatou
# Processing Record 44 of Set 11 | jalal-abad
# Processing Record 45 of Set 11 | matias barbosa
# Processing Record 46 of Set 11 | silainiai
# City not found. Skipping...
# Processing Record 47 of Set 11 | villa gesell
# Processing Record 48 of Set 11 | lewistown
# Processing Record 49 of Set 11 | barcelos
# Processing Record 0 of Set 12 | fuerte olimpo
# Processing Record 1 of Set 12 | phan rang-thap cham
# Processing Record 2 of Set 12 | guajara
# Processing Record 3 of Set 12 | flying fish cove
# Processing Record 4 of Set 12 | naze
# Processing Record 5 of Set 12 | kollam
# Processing Record 6 of Set 12 | tarawa
# Processing Record 7 of Set 12 | qandala
# Processing Record 8 of Set 12 | leticia
# Processing Record 9 of Set 12 | basey
# Processing Record 10 of Set 12 | palmas
# Processing Record 11 of Set 12 | yeppoon
# Processing Record 12 of Set 12 | isla aguada
# Processing Record 13 of Set 12 | tanki leendert
# City not found. Skipping...
# Processing Record 14 of Set 12 | bukittinggi
# Processing Record 15 of Set 12 | mugumu
# Processing Record 16 of Set 12 | pangai
# Processing Record 17 of Set 12 | tyukhtet
# Processing Record 18 of Set 12 | ola
# Processing Record 19 of Set 12 | chalus
# Processing Record 20 of Set 12 | carutapera
# Processing Record 21 of Set 12 | sulak
# Processing Record 22 of Set 12 | nadym
# Processing Record 23 of Set 12 | terenozek
# Processing Record 24 of Set 12 | selfoss
# Processing Record 25 of Set 12 | offanengo
# Processing Record 26 of Set 12 | malanje
# Processing Record 27 of Set 12 | horta
# Processing Record 28 of Set 12 | farafangana
# Processing Record 29 of Set 12 | caras
# Processing Record 30 of Set 12 | san antonio
# Processing Record 31 of Set 12 | zell am see
# Processing Record 32 of Set 12 | cesme
# Processing Record 33 of Set 12 | kirakira
# Processing Record 34 of Set 12 | manapparai
# Processing Record 35 of Set 12 | kaedi
# Processing Record 36 of Set 12 | san-pedro
# Processing Record 37 of Set 12 | zaozersk
# Processing Record 38 of Set 12 | lembar
# City not found. Skipping...
# Processing Record 39 of Set 12 | carandai
# Processing Record 40 of Set 12 | muisne
# Processing Record 41 of Set 12 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 42 of Set 12 | borzya
# Processing Record 43 of Set 12 | magadan
# Processing Record 44 of Set 12 | kavaratti
# Processing Record 45 of Set 12 | leava
# Processing Record 46 of Set 12 | nizhnyaya poyma
# Processing Record 47 of Set 12 | al khafji
# Processing Record 48 of Set 12 | celestun
# Processing Record 49 of Set 12 | bikenibeu village
# Processing Record 0 of Set 13 | hassi messaoud
# Processing Record 1 of Set 13 | kalamnuri
# Processing Record 2 of Set 13 | inhambane
# Processing Record 3 of Set 13 | juva
# Processing Record 4 of Set 13 | tshabong
# Processing Record 5 of Set 13 | jianshui
# Processing Record 6 of Set 13 | inari
# Processing Record 7 of Set 13 | scone
# Processing Record 8 of Set 13 | tataouine
# Processing Record 9 of Set 13 | shimoda
# Processing Record 10 of Set 13 | iskateley
# Processing Record 11 of Set 13 | eyl
# Processing Record 12 of Set 13 | puerto armuelles
# Processing Record 13 of Set 13 | zemio
# Processing Record 14 of Set 13 | goroka
# Processing Record 15 of Set 13 | andalgala
# Processing Record 16 of Set 13 | weno
# Processing Record 17 of Set 13 | houma
# Processing Record 18 of Set 13 | tangalle
# Processing Record 19 of Set 13 | nizhneangarsk
# Processing Record 20 of Set 13 | lorengau
# Processing Record 21 of Set 13 | khovd
# Processing Record 22 of Set 13 | mont-joli
# Processing Record 23 of Set 13 | opuwo
# Processing Record 24 of Set 13 | coxen hole
# Processing Record 25 of Set 13 | senj
# Processing Record 26 of Set 13 | altai
# Processing Record 27 of Set 13 | balaipungut
# Processing Record 28 of Set 13 | talant
# Processing Record 29 of Set 13 | maragogi
# Processing Record 30 of Set 13 | palamos
# Processing Record 31 of Set 13 | abadeh
# Processing Record 32 of Set 13 | costa calma
# City not found. Skipping...
# Processing Record 33 of Set 13 | kabalo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          600
# Lat           600
# Lng           600
# Max Temp      600
# Humidity      600
# Cloudiness    600
# Wind Speed    600
# Country       600
# Date          600
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        bilibino  68.0546  166.4372     53.87        84         100
# 1       lambarene  -0.7001   10.2406     70.25        93          70
# 2     olonkinbyen  70.9221   -8.7187     41.41        90         100
# 3  ash shihaniyah  25.3686   51.2264     94.62        37         100
# 4        quilmana -12.9500  -76.3833     66.07        82          35
#
#    Wind Speed Country        Date
# 0        1.63      RU  1690254868
# 1        2.68      GA  1690254932
# 2       10.54      SJ  1690254932
# 3        3.83      QA  1690254933
# 4        2.19      PE  1690254933

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              bilibino  68.0546  166.4372     53.87        84         100
# 1             lambarene  -0.7001   10.2406     70.25        93          70
# 2           olonkinbyen  70.9221   -8.7187     41.41        90         100
# 3        ash shihaniyah  25.3686   51.2264     94.62        37         100
# 4              quilmana -12.9500  -76.3833     66.07        82          35
#
#          Wind Speed Country        Date
# City_ID
# 0              1.63      RU  1690254868
# 1              2.68      GA  1690254932
# 2             10.54      SJ  1690254932
# 3              3.83      QA  1690254933
# 4              2.19      PE  1690254933

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker = 'o', edgecolor="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker = 'o', edgecolor="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], marker = 'o')

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt. grid(True)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], marker = 'o')


# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
#####LAT VS. TEMP#####
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20, 30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title('Latitude vs. Max Temp')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.04482336956558943

# %%
# Define a function to create Linear Regression plots
#####LAT VS. HUMIDITY#####
x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Latitude vs. Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0064669812008071835

# %%
# Define a function to create Linear Regression plots
#####LAT VS. CLOUDINESS#####
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Latitude vs. Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0010191092697761602

# %%
# Define a function to create Linear Regression plots
#####LAT VS. WIND SPEED#####
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Latitude vs. Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.010884202044696433

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              bilibino  68.0546  166.4372     53.87        84         100
# 2           olonkinbyen  70.9221   -8.7187     41.41        90         100
# 3        ash shihaniyah  25.3686   51.2264     94.62        37         100
# 5              harrison  30.4091  -89.0436     80.65        77           0
# 6             boa vista   2.8197  -60.6733     78.78        83          20
#
#          Wind Speed Country        Date
# City_ID
# 0              1.63      RU  1690254868
# 2             10.54      SJ  1690254932
# 3              3.83      QA  1690254933
# 5              0.00      US  1690254933
# 6              1.14      BR  1690254933

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        lambarene  -0.7001   10.2406     70.25        93          70
# 4         quilmana -12.9500  -76.3833     66.07        82          35
# 9          ushuaia -54.8000  -68.3000     29.86        69           0
# 11       adamstown -25.0660 -130.1015     68.95        71          16
# 13         chonchi -42.6128  -73.8092     47.41        91          74
#
#          Wind Speed Country        Date
# City_ID
# 1              2.68      GA  1690254932
# 4              2.19      PE  1690254933
# 9              2.30      AR  1690254789
# 11             9.64      PN  1690254934
# 13             6.60      CL  1690254934

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title('Latitude vs. Max Temp')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.3072992201425589

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title('Latitude vs. Max Temp')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.6981757473265263

# %% [markdown]
# **Discussion about the linear relationship:** The r-value of 0.698 suggests that there is a weak to moderate correlation between latitude and max temp in the southern hemisphere

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Latitude vs. Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0030936611150122976

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Latitude vs. Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.00966440295421595

# %% [markdown]
# **Discussion about the linear relationship:** the r-value of 0.096 suggests that there is a weak positive correlation between latitude and humidity in the southern hemisphere

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Latitude vs. Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.005278878992910161

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.04523089821230584

# %% [markdown]
# **Discussion about the linear relationship:** the r-value of 0.045 suggests that there is moderate positive correlation between latitude and cloudiness in the southern hemisphere

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, color="red")
plt.annotate(line_eq,(-20,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Latitude vs. Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.017590617290046243

# %%
# Southern Hemisphere

x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, color="red")
plt.annotate(line_eq,(-20,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Latitude vs. Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0036182468094346464

# %% [markdown]
# **Discussion about the linear relationship:** the r-value of 0.0036 suggests that there is a weak negative correlation between latitude and wind speed in the southern hemisphere
